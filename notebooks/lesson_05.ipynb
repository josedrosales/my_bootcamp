# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df1 = pd.read_csv("../data/ACCIDENTS_GU_BCN_2010.csv",encoding="latin-1")
df1.head()
# Out:
#   Número d'expedient  Codi districte Nom districte   NK barri  \
# 0        2010S003688              10    Sant Martí  101-10-64
# 1        2010S007597              10    Sant Martí  101-10-64
# 2        2010S001390              10    Sant Martí  101-10-64
# 3        2010S005416              10    Sant Martí  101-10-64
# 4        2010S008924              10    Sant Martí  101-10-64
#
#                     Nom barri  Codi carrer                Nom carrer  \
# 0  el Camp de l'Arpa del Clot       209900                 Meridiana
# 1  el Camp de l'Arpa del Clot       346402                  Trinxant
# 2  el Camp de l'Arpa del Clot       297001  Sant Antoni Maria Claret
# 3  el Camp de l'Arpa del Clot       134801                    Freser
# 4  el Camp de l'Arpa del Clot       161407                 Indústria
#
#   Num postal caption Descripció dia setmana  Dia de setmana  ... Hora de dia  \
# 0          0181 0181              Divendres               5  ...          19
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9056 entries, 0 to 9055
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Número d'expedient            9056 non-null   object
#  1   Codi districte                9056 non-null   int64
#  2   Nom districte                 9056 non-null   object
#  3   NK barri                      9056 non-null   object
#  4   Nom barri                     9056 non-null   object
#  5   Codi carrer                   9056 non-null   int64
#  6   Nom carrer                    9056 non-null   object
#  7   Num postal caption            9056 non-null   object
#  8   Descripció dia setmana        9056 non-null   object
#  9   Dia de setmana                9056 non-null   int64
#  10  Descripció tipus dia          9056 non-null   object
#  11  NK Any                        9056 non-null   int64
# ...

# %%
df1['Date'] = df1[u"Dia de mes"].apply(lambda x: str(x)) + "-" + df1[u"Mes de any"].apply(lambda x: str(x)) + "-2010"
df1["Date"] = pd.to_datetime(df1["Date"], format="%d-%m-%Y")
df1.sample(6)
# Out:
#      Número d'expedient  Codi districte        Nom districte NK barri  \
# 8055        2010S005080               2             Eixample  21-2-10
# 376         2010S000981               5  Sarrià-Sant Gervasi  51-5-26
# 364         2010S008892               4            Les Corts  42-4-20
# 4508        2010S002519               8           Nou Barris  82-8-53
# 6438        2010S003680               2             Eixample   24-2-7
# 3809        2010S003530               5  Sarrià-Sant Gervasi  53-5-27
#
#                        Nom barri  Codi carrer       Nom carrer  \
# 8055                 Sant Antoni       127704    Floridablanca
# 376       Sant Gervasi - Galvany        28000          Augusta
# 364   la Maternitat i Sant Ramon       343903            Corts
# 4508            la Trinitat Nova       132205            Fosca
# 6438      la Dreta de l'Eixample       169409  Corts Catalanes
# 3809        el Putxet i el Farró       302000     Sant Gervasi
#
# ...

# %%
accidents_2010 = df1.groupby(["Date"]).size()
print("accidents", accidents_2010.mean())
# Out:
# accidents 24.81095890410959

# %%
df2 = pd.read_csv("../data/ACCIDENTS_GU_BCN_2013.csv",encoding="latin-1")
df2.head()
# Out:
#   Número d'expedient  Codi districte Nom districte   NK barri  \
# 0        2013S007360              -1    Desconegut   -1--1--1
# 1        2013S007723              10    Sant Martí  101-10-64
# 2        2013S005373              10    Sant Martí  101-10-64
# 3        2013S001486              10    Sant Martí  101-10-64
# 4        2013S008254              10    Sant Martí  101-10-64
#
#                     Nom barri  Codi carrer     Nom carrer Num postal caption  \
# 0                  Desconegut           -1     Desconegut         Desconegut
# 1  el Camp de l'Arpa del Clot       152600       Guinardó          0028 0032
# 2  el Camp de l'Arpa del Clot       134801         Freser          0053 0053
# 3  el Camp de l'Arpa del Clot       161407      Indústria          0224 0224
# 4  el Camp de l'Arpa del Clot       161101  Independència          0357 0357
#
#   Descripció dia setmana  Dia de setmana  ... Hora de dia  Descripció torn  \
# ...

# %%
df2['Date'] = df2[u"Dia de mes"].apply(lambda x: str(x)) + "-" + df2[u"Mes de any"].apply(lambda x: str(x)) + "-2013"
df2["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")
df2.sample(6)
# Out:
#      Número d'expedient  Codi districte   Nom districte NK barri  \
# 6139        2013S002656               3  Sants-Montjuïc  31-3-11
# 6186        2013S007662               3  Sants-Montjuïc  33-3-15
# 3183        2013S001724               3  Sants-Montjuïc  34-3-17
# 3786        2013S008984               3  Sants-Montjuïc  32-3-12
# 8540        2013S006658               4       Les Corts  41-4-19
# 9146        2013S005635               3  Sants-Montjuïc  32-3-12
#
#                        Nom barri  Codi carrer            Nom carrer  \
# 6139                el Poble Sec       116402                Estadi
# 6186                 Hostafrancs       169409       Corts Catalanes
# 3183               Sants - Badal        36100             Bassegoda
# 3786  la Marina del Prat Vermell       700121        Longitudinal 7
# 8540                   les Corts       186907                 Lluçà
# 9146  la Marina del Prat Vermell       370305  Número 4 Zona Franca
#
# ...

# %%
accidents_2013 = df2.groupby(["Date"]).size()
print("accidents", accidents_2013.mean())
# Out:
# accidents 25.90958904109589

# %%
accidents_df1 = accidents_2010.to_frame()
rows = np.random.choice(accidents_df1.index.values,200)
sample_df1 = accidents_df1.loc[rows]
est_std = sample_df1.std()
print("estimado desv estandar",est_std)
est_mean = sample_df1.mean()
print("estimado media",est_mean)
# Out:
# estimado desv estandar 0    8.402798
# dtype: float64
# estimado media 0    24.105
# dtype: float64

# %%
#la tecnica de bootstraping es simular que la muestra
#tiene suficiente informacion de la distribucion subyacente
#y se aplica haciendo un muestreo con reemplazo para aproximar 
#los parametros de la poblacion

# los intervalos de confianza del z_score 10% improbable = 1.165
#5% improbable = 1.96, 1% improbable = 2.58 +/-


mean_2010 = accidents_2010.mean()
std_2010 = accidents_2010.std()
n = len(accidents_2010) 
ci = [mean_2010 - std_2010 * 1.96 / np.sqrt(n),mean_2010 + std_2010 * 1.96 / np.sqrt(n)]
print(ci)
# Out:
# [np.float64(23.93287194410715), np.float64(25.689045864112032)]

# %%
mean_2013 = accidents_2013.mean()
std_2013 = accidents_2013.std()
n_2013 = len(accidents_2013) 
ci = [mean_2013 - std_2013 * 1.96 / np.sqrt(n_2013),mean_2013 + std_2013 * 1.96 / np.sqrt(n_2013)]
print(ci)
# Out:
# [np.float64(24.975156065800284), np.float64(26.8440220163915)]

# %%
#Nivel de significancia alpha = 0.05

Z_score = (mean_2010 - mean_2013)/np.sqrt(std_2010/n + std_2013/n_2013)
print(Z_score)
# Out:
# -4.993572550110768
